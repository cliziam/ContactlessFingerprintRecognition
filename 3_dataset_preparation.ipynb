# %%
import os
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
import shutil

from google.colab import drive
drive.mount('/content/drive')

# %cd "drive/MyDrive/biometric"

# %% [markdown]
# Through the use of NFIQ2 from command line, a csv file "quality_scores.json" was generated with the values that contain the quality score of each image.

# %%
pd.set_option('display.max_rows', 100)
cols=["Filename", "QualityScore"]
df = pd.read_csv("/utils/quality_scores.csv", usecols=cols)
df
# Out:
#                                         Filename  QualityScore
# 0     Livescan_500/Natural/Indoor/10_i_1_n_1.png            59
# 1     Livescan_500/Natural/Indoor/10_i_1_n_2.png            64
# 2     Livescan_500/Natural/Indoor/10_i_1_n_3.png            66
# 3     Livescan_500/Natural/Indoor/10_i_1_n_4.png            58
# 4     Livescan_500/Natural/Indoor/10_i_1_n_5.png            58
# ...                                          ...           ...
# 4091    Livescan_500/White/Outdoor/9_o_2_w_4.png            48
# 4092    Livescan_500/White/Outdoor/9_o_2_w_5.png            49
# 4093    Livescan_500/White/Outdoor/9_o_2_w_6.png            43
# 4094    Livescan_500/White/Outdoor/9_o_2_w_7.png            37
# 4095    Livescan_500/White/Outdoor/9_o_2_w_8.png            40
#
# [4096 rows x 2 columns]

# %% [markdown]
# # Dataset organisation
# In this notebook we prepare the dataset to be used during the experiments:
# 1. we remove the worst 6 samples for each different finger recorded;
# 2. we split in train and test set;
# 3. we split both train and test sets in probe and gallery (for the test set, this split is repeated 5 times in order to have statistically reliable scores).
#
# Note that originally we have 64 different identities, and 2 fingers for each identity. Since each finger is independent, we can treat different fingers as different subjects, so we have a total of 64 $\cdot$ 2 = 128 identities.

# %% [markdown]
# ## 1. Remove bad samples for each finger

# %%
Filenames = list(df['Filename'])
Qualities = list(df['QualityScore'])

identities = []
fingers = []
for filename in Filenames:
  info = filename.split('/')
  splitted_info = info[-1].split("_")
  identities.append(int(splitted_info[0]))
  fingers.append(int(splitted_info[2]))

df['identity'] = identities
df['finger'] = fingers
df.head(30)
# Out:
#                                       Filename  QualityScore  identity  finger
# 0   Livescan_500/Natural/Indoor/10_i_1_n_1.png            59        10       1
# 1   Livescan_500/Natural/Indoor/10_i_1_n_2.png            64        10       1
# 2   Livescan_500/Natural/Indoor/10_i_1_n_3.png            66        10       1
# 3   Livescan_500/Natural/Indoor/10_i_1_n_4.png            58        10       1
# 4   Livescan_500/Natural/Indoor/10_i_1_n_5.png            58        10       1
# 5   Livescan_500/Natural/Indoor/10_i_1_n_6.png            62        10       1
# 6   Livescan_500/Natural/Indoor/10_i_1_n_7.png            55        10       1
# 7   Livescan_500/Natural/Indoor/10_i_1_n_8.png            59        10       1
# 8   Livescan_500/Natural/Indoor/10_i_2_n_1.png            41        10       2
# 9   Livescan_500/Natural/Indoor/10_i_2_n_2.png            37        10       2
# 10  Livescan_500/Natural/Indoor/10_i_2_n_3.png            43        10       2
# 11  Livescan_500/Natural/Indoor/10_i_2_n_4.png            40        10       2
# 12  Livescan_500/Natural/Indoor/10_i_2_n_5.png            42        10       2
# 13  Livescan_500/Natural/Indoor/10_i_2_n_6.png            37        10       2
# 14  Livescan_500/Natural/Indoor/10_i_2_n_7.png            36        10       2
# 15  Livescan_500/Natural/Indoor/10_i_2_n_8.png            36        10       2
# 16  Livescan_500/Natural/Indoor/11_i_1_n_1.png            53        11       1
# 17  Livescan_500/Natural/Indoor/11_i_1_n_2.png            49        11       1
# 18  Livescan_500/Natural/Indoor/11_i_1_n_3.png            53        11       1
# 19  Livescan_500/Natural/Indoor/11_i_1_n_4.png            48        11       1
# 20  Livescan_500/Natural/Indoor/11_i_1_n_5.png            46        11       1
# 21  Livescan_500/Natural/Indoor/11_i_1_n_6.png            52        11       1
# 22  Livescan_500/Natural/Indoor/11_i_1_n_7.png            43        11       1
# 23  Livescan_500/Natural/Indoor/11_i_1_n_8.png            48        11       1
# 24  Livescan_500/Natural/Indoor/11_i_2_n_1.png            42        11       2
# 25  Livescan_500/Natural/Indoor/11_i_2_n_2.png            39        11       2
# 26  Livescan_500/Natural/Indoor/11_i_2_n_3.png            48        11       2
# 27  Livescan_500/Natural/Indoor/11_i_2_n_4.png            41        11       2
# 28  Livescan_500/Natural/Indoor/11_i_2_n_6.png            40        11       2
# 29  Livescan_500/Natural/Indoor/11_i_2_n_7.png            33        11       2

# %%
grouped_df = df.groupby(by=["identity", "finger"])
dataframes = [grouped_df.get_group(x) for x in grouped_df.groups]
sorted_dataframes = [df.sort_values("QualityScore") for df in dataframes]
cleaned_dataframes = [df.iloc[6:] for df in sorted_dataframes] # remove worst 6 samples for each finger

# %%
# record paths of images to keep
valid_samples = []
for df in cleaned_dataframes:
  valid_samples += list(df["Filename"])

cleaned_paths = []
for path in valid_samples:
  cleaned_paths.append(path.split("/")[-1])

# %%
# write list of paths to json file
dict_valid_samples = dict()
dict_valid_samples["samples_list"] = cleaned_paths

with open("utils/valid_samples.json", "w") as f:
  json.dump(dict_valid_samples, f)

# %%
# load list of paths from json file
with open("utils/valid_samples.json") as json_file:
    data = json.load(json_file)
valid_list = data["samples_list"]

for file in os.listdir("LivescanUnified"):
    if file not in valid_list:
        os.remove(os.path.join("LivescanUnified", file))

# %% [markdown]
# ## 2. Split in train and test set
# We decided to keep only the outdoor datasets for computational reasons and because they have average better quality. Then we use 70% of data for train set and 30% for test set. All identities will have equal number of samples in train and test sets (choice based on samples rather than subjects).

# %%
# read all the files in the folder "LivescanUnified", remove middle fingers and organize the remaining in a dict
ids_to_file = {}
for file in os.listdir("LivescanUnified"):
    infos = file.split('_')

    if infos[2] == '2': # remove middle fingers
        os.remove(os.path.join("LivescanUnified", file))

    else:
        id = infos[0]
        if id in ids_to_file:
            ids_to_file[id].append(file)
        else:
            ids_to_file[id] = [file]

ids_to_file
# Out:
# {'10': ['10_o_1_n_1.png',
#   '10_o_1_n_6.png',
#   '10_o_1_w_6.png',
#   '10_o_1_n_2.png',
#   '10_o_1_w_3.png',
#   '10_o_1_w_7.png',
#   '10_o_1_n_3.png',
#   '10_o_1_n_7.png',
#   '10_o_1_w_8.png',
#   '10_o_1_w_2.png',
#   '10_o_1_w_5.png',
#   '10_o_1_w_4.png',
#   '10_o_1_n_4.png',
#   '10_o_1_w_1.png',
#   '10_o_1_n_5.png',
#   '10_o_1_n_8.png'],
#  '18': ['18_o_1_w_1.png',
#   '18_o_1_n_7.png',
#   '18_o_1_w_6.png',
#   '18_o_1_w_7.png',
#   '18_o_1_w_2.png',
#   '18_o_1_n_4.png',
#   '18_o_1_n_2.png',
#   '18_o_1_w_5.png',
#   '18_o_1_w_4.png',
#   '18_o_1_w_3.png',
#   '18_o_1_n_8.png',
#   '18_o_1_w_8.png',
#   '18_o_1_n_6.png',
#   '18_o_1_n_1.png',
#   '18_o_1_n_3.png',
#   '18_o_1_n_5.png'],
#  '35': ['35_o_1_w_3.png',
#   '35_o_1_n_1.png',
#   '35_o_1_n_4.png',
#   '35_o_1_n_3.png',
#   '35_o_1_w_7.png',
#   '35_o_1_w_2.png',
#   '35_o_1_w_5.png',
#   '35_o_1_n_7.png',
#   '35_o_1_w_1.png',
#   '35_o_1_w_4.png',
#   '35_o_1_n_5.png',
#   '35_o_1_n_6.png',
#   '35_o_1_n_2.png',
#   '35_o_1_n_8.png',
#   '35_o_1_w_8.png',
#   '35_o_1_w_6.png'],
#  '1': ['1_o_1_w_4.png',
#   '1_o_1_w_2.png',
#   '1_o_1_n_5.png',
#   '1_o_1_w_8.png',
#   '1_o_1_w_1.png',
#   '1_o_1_n_2.png',
#   '1_o_1_w_5.png',
#   '1_o_1_w_7.png',
#   '1_o_1_n_8.png',
#   '1_o_1_n_6.png',
#   '1_o_1_n_1.png',
#   '1_o_1_n_4.png',
#   '1_o_1_n_3.png',
#   '1_o_1_n_7.png',
#   '1_o_1_w_3.png',
#   '1_o_1_w_6.png'],
#  '23': ['23_o_1_w_3.png',
#   '23_o_1_n_5.png',
#   '23_o_1_n_1.png',
#   '23_o_1_n_2.png',
#   '23_o_1_w_7.png',
#   '23_o_1_w_8.png',
#   '23_o_1_w_1.png',
#   '23_o_1_n_3.png',
#   '23_o_1_w_2.png',
#   '23_o_1_n_7.png',
#   '23_o_1_w_4.png',
#   '23_o_1_n_4.png',
#   '23_o_1_w_5.png',
#   '23_o_1_w_6.png',
#   '23_o_1_n_8.png',
#   '23_o_1_n_6.png'],
#  '57': ['57_o_1_n_7.png',
#   '57_o_1_n_6.png',
#   '57_o_1_w_4.png',
#   '57_o_1_n_2.png',
#   '57_o_1_n_8.png',
#   '57_o_1_n_5.png',
#   '57_o_1_w_2.png',
#   '57_o_1_w_3.png',
#   '57_o_1_w_7.png',
#   '57_o_1_n_4.png',
#   '57_o_1_w_8.png',
#   '57_o_1_n_3.png',
#   '57_o_1_n_1.png',
#   '57_o_1_w_1.png',
#   '57_o_1_w_5.png',
#   '57_o_1_w_6.png'],
#  '8': ['8_o_1_w_2.png',
#   '8_o_1_w_4.png',
#   '8_o_1_n_2.png',
#   '8_o_1_w_8.png',
#   '8_o_1_n_6.png',
#   '8_o_1_w_7.png',
#   '8_o_1_w_1.png',
#   '8_o_1_w_6.png',
#   '8_o_1_n_1.png',
#   '8_o_1_n_3.png',
#   '8_o_1_n_5.png',
#   '8_o_1_n_7.png',
#   '8_o_1_n_8.png',
#   '8_o_1_w_5.png',
#   '8_o_1_n_4.png',
#   '8_o_1_w_3.png'],
#  '16': ['16_o_1_n_1.png',
#   '16_o_1_n_5.png',
#   '16_o_1_n_2.png',
#   '16_o_1_n_8.png',
#   '16_o_1_n_6.png',
#   '16_o_1_w_7.png',
#   '16_o_1_w_5.png',
#   '16_o_1_w_1.png',
#   '16_o_1_n_4.png',
#   '16_o_1_w_2.png',
#   '16_o_1_n_3.png',
#   '16_o_1_w_6.png',
#   '16_o_1_n_7.png',
#   '16_o_1_w_8.png',
#   '16_o_1_w_3.png',
#   '16_o_1_w_4.png'],
#  '45': ['45_o_1_w_4.png',
#   '45_o_1_n_5.png',
#   '45_o_1_w_5.png',
#   '45_o_1_n_3.png',
#   '45_o_1_w_8.png',
#   '45_o_1_n_8.png',
#   '45_o_1_n_1.png',
#   '45_o_1_n_4.png',
#   '45_o_1_w_7.png',
#   '45_o_1_n_7.png',
#   '45_o_1_w_1.png',
#   '45_o_1_n_6.png',
#   '45_o_1_w_6.png',
#   '45_o_1_w_2.png',
#   '45_o_1_n_2.png',
#   '45_o_1_w_3.png'],
#  '25': ['25_o_1_w_7.png',
#   '25_o_1_n_2.png',
#   '25_o_1_w_6.png',
#   '25_o_1_w_1.png',
#   '25_o_1_n_6.png',
#   '25_o_1_w_5.png',
#   '25_o_1_w_4.png',
#   '25_o_1_n_7.png',
#   '25_o_1_w_3.png',
#   '25_o_1_n_5.png',
#   '25_o_1_w_8.png',
#   '25_o_1_n_4.png',
#   '25_o_1_n_1.png',
#   '25_o_1_n_8.png',
#   '25_o_1_n_3.png',
#   '25_o_1_w_2.png'],
#  '46': ['46_o_1_w_8.png',
#   '46_o_1_n_4.png',
#   '46_o_1_n_1.png',
#   '46_o_1_w_5.png',
#   '46_o_1_w_2.png',
#   '46_o_1_w_4.png',
#   '46_o_1_n_7.png',
#   '46_o_1_n_3.png',
#   '46_o_1_w_7.png',
#   '46_o_1_w_6.png',
#   '46_o_1_n_8.png',
#   '46_o_1_n_5.png',
#   '46_o_1_w_1.png',
#   '46_o_1_w_3.png',
#   '46_o_1_n_2.png',
#   '46_o_1_n_6.png'],
#  '15': ['15_o_1_w_3.png',
#   '15_o_1_w_6.png',
#   '15_o_1_n_1.png',
#   '15_o_1_w_1.png',
#   '15_o_1_n_5.png',
#   '15_o_1_w_2.png',
#   '15_o_1_w_8.png',
#   '15_o_1_w_4.png',
#   '15_o_1_n_6.png',
#   '15_o_1_n_4.png',
#   '15_o_1_n_8.png',
#   '15_o_1_n_3.png',
#   '15_o_1_n_2.png',
#   '15_o_1_w_5.png',
#   '15_o_1_w_7.png',
#   '15_o_1_n_7.png'],
#  '31': ['31_o_1_w_7.png',
#   '31_o_1_w_4.png',
#   '31_o_1_n_8.png',
#   '31_o_1_w_2.png',
#   '31_o_1_n_2.png',
#   '31_o_1_n_5.png',
#   '31_o_1_w_6.png',
#   '31_o_1_n_4.png',
#   '31_o_1_w_8.png',
#   '31_o_1_n_6.png',
#   '31_o_1_n_1.png',
#   '31_o_1_w_3.png',
#   '31_o_1_w_1.png',
#   '31_o_1_w_5.png',
#   '31_o_1_n_7.png',
#   '31_o_1_n_3.png'],
#  '47': ['47_o_1_w_8.png',
#   '47_o_1_n_1.png',
#   '47_o_1_w_4.png',
#   '47_o_1_n_5.png',
#   '47_o_1_w_1.png',
#   '47_o_1_w_2.png',
#   '47_o_1_w_6.png',
#   '47_o_1_n_2.png',
#   '47_o_1_w_7.png',
#   '47_o_1_n_8.png',
#   '47_o_1_n_3.png',
#   '47_o_1_w_3.png',
#   '47_o_1_w_5.png',
#   '47_o_1_n_4.png',
#   '47_o_1_n_7.png',
#   '47_o_1_n_6.png'],
#  '7': ['7_o_1_n_7.png',
#   '7_o_1_w_1.png',
#   '7_o_1_w_2.png',
#   '7_o_1_n_6.png',
#   '7_o_1_w_4.png',
#   '7_o_1_n_8.png',
#   '7_o_1_n_2.png',
#   '7_o_1_w_8.png',
#   '7_o_1_n_3.png',
#   '7_o_1_w_7.png',
#   '7_o_1_w_5.png',
#   '7_o_1_n_4.png',
#   '7_o_1_n_1.png',
#   '7_o_1_n_5.png',
#   '7_o_1_w_6.png',
#   '7_o_1_w_3.png'],
#  '59': ['59_o_1_w_5.png',
#   '59_o_1_n_8.png',
#   '59_o_1_w_4.png',
#   '59_o_1_n_5.png',
#   '59_o_1_n_7.png',
#   '59_o_1_w_3.png',
#   '59_o_1_n_2.png',
#   '59_o_1_n_3.png',
#   '59_o_1_n_4.png',
#   '59_o_1_w_6.png',
#   '59_o_1_w_1.png',
#   '59_o_1_n_6.png',
#   '59_o_1_w_7.png',
#   '59_o_1_n_1.png',
#   '59_o_1_w_8.png',
#   '59_o_1_w_2.png'],
#  '13': ['13_o_1_w_6.png',
#   '13_o_1_w_1.png',
#   '13_o_1_w_4.png',
#   '13_o_1_n_3.png',
#   '13_o_1_w_7.png',
#   '13_o_1_w_2.png',
#   '13_o_1_w_5.png',
#   '13_o_1_n_5.png',
#   '13_o_1_n_2.png',
#   '13_o_1_n_8.png',
#   '13_o_1_w_8.png',
#   '13_o_1_n_6.png',
#   '13_o_1_n_7.png',
#   '13_o_1_n_1.png',
#   '13_o_1_n_4.png',
#   '13_o_1_w_3.png'],
#  '21': ['21_o_1_n_7.png',
#   '21_o_1_w_1.png',
#   '21_o_1_n_8.png',
#   '21_o_1_w_3.png',
#   '21_o_1_w_4.png',
#   '21_o_1_n_5.png',
#   '21_o_1_n_3.png',
#   '21_o_1_w_6.png',
#   '21_o_1_n_1.png',
#   '21_o_1_w_8.png',
#   '21_o_1_w_2.png',
#   '21_o_1_n_2.png',
#   '21_o_1_w_7.png',
#   '21_o_1_n_4.png',
#   '21_o_1_w_5.png',
#   '21_o_1_n_6.png'],
#  '29': ['29_o_1_n_4.png',
#   '29_o_1_n_5.png',
#   '29_o_1_w_6.png',
#   '29_o_1_w_7.png',
#   '29_o_1_n_1.png',
#   '29_o_1_w_8.png',
#   '29_o_1_w_3.png',
#   '29_o_1_w_2.png',
#   '29_o_1_n_3.png',
#   '29_o_1_n_7.png',
#   '29_o_1_w_1.png',
#   '29_o_1_w_5.png',
#   '29_o_1_w_4.png',
#   '29_o_1_n_2.png',
#   '29_o_1_n_6.png',
#   '29_o_1_n_8.png'],
#  '38': ['38_o_1_w_8.png',
#   '38_o_1_n_1.png',
#   '38_o_1_n_2.png',
#   '38_o_1_n_7.png',
#   '38_o_1_n_6.png',
#   '38_o_1_w_7.png',
#   '38_o_1_n_3.png',
#   '38_o_1_n_8.png',
#   '38_o_1_w_2.png',
#   '38_o_1_w_6.png',
#   '38_o_1_w_1.png',
#   '38_o_1_n_4.png',
#   '38_o_1_w_5.png',
#   '38_o_1_n_5.png',
#   '38_o_1_w_4.png',
#   '38_o_1_w_3.png'],
#  '17': ['17_o_1_n_2.png',
#   '17_o_1_n_7.png',
#   '17_o_1_w_6.png',
#   '17_o_1_n_3.png',
#   '17_o_1_w_8.png',
#   '17_o_1_w_1.png',
#   '17_o_1_w_2.png',
#   '17_o_1_w_5.png',
#   '17_o_1_n_5.png',
#   '17_o_1_n_8.png',
#   '17_o_1_n_6.png',
#   '17_o_1_n_4.png',
#   '17_o_1_w_4.png',
#   '17_o_1_n_1.png',
#   '17_o_1_w_3.png',
#   '17_o_1_w_7.png'],
#  '60': ['60_o_1_w_3.png',
#   '60_o_1_n_3.png',
#   '60_o_1_n_7.png',
#   '60_o_1_n_1.png',
#   '60_o_1_n_8.png',
#   '60_o_1_n_2.png',
#   '60_o_1_w_8.png',
#   '60_o_1_w_2.png',
#   '60_o_1_w_1.png',
#   '60_o_1_n_4.png',
#   '60_o_1_w_7.png',
#   '60_o_1_n_6.png',
#   '60_o_1_w_5.png',
#   '60_o_1_n_5.png',
#   '60_o_1_w_4.png',
#   '60_o_1_w_6.png'],
#  '11': ['11_o_1_n_3.png',
#   '11_o_1_n_8.png',
#   '11_o_1_n_5.png',
#   '11_o_1_n_1.png',
#   '11_o_1_n_7.png',
#   '11_o_1_n_4.png',
#   '11_o_1_w_4.png',
#   '11_o_1_w_3.png',
#   '11_o_1_w_6.png',
#   '11_o_1_n_6.png',
#   '11_o_1_w_1.png',
#   '11_o_1_w_7.png',
#   '11_o_1_w_2.png',
#   '11_o_1_w_8.png',
#   '11_o_1_n_2.png',
#   '11_o_1_w_5.png'],
#  '52': ['52_o_1_w_6.png',
#   '52_o_1_n_7.png',
#   '52_o_1_n_4.png',
#   '52_o_1_w_8.png',
#   '52_o_1_w_3.png',
#   '52_o_1_w_7.png',
#   '52_o_1_w_5.png',
#   '52_o_1_w_2.png',
#   '52_o_1_n_5.png',
#   '52_o_1_w_1.png',
#   '52_o_1_n_2.png',
#   '52_o_1_n_6.png',
#   '52_o_1_n_8.png',
#   '52_o_1_n_1.png',
#   '52_o_1_n_3.png',
#   '52_o_1_w_4.png'],
#  '40': ['40_o_1_w_3.png',
#   '40_o_1_w_1.png',
#   '40_o_1_n_7.png',
#   '40_o_1_w_2.png',
#   '40_o_1_n_6.png',
#   '40_o_1_w_4.png',
#   '40_o_1_w_6.png',
#   '40_o_1_n_3.png',
#   '40_o_1_w_8.png',
#   '40_o_1_n_5.png',
#   '40_o_1_n_8.png',
#   '40_o_1_n_4.png',
#   '40_o_1_n_2.png',
#   '40_o_1_w_5.png',
#   '40_o_1_n_1.png',
#   '40_o_1_w_7.png'],
#  '44': ['44_o_1_w_4.png',
#   '44_o_1_w_2.png',
#   '44_o_1_n_2.png',
#   '44_o_1_n_8.png',
#   '44_o_1_w_8.png',
#   '44_o_1_n_6.png',
#   '44_o_1_n_1.png',
#   '44_o_1_n_3.png',
#   '44_o_1_w_6.png',
#   '44_o_1_n_7.png',
#   '44_o_1_w_5.png',
#   '44_o_1_n_5.png',
#   '44_o_1_w_1.png',
#   '44_o_1_n_4.png',
#   '44_o_1_w_7.png',
#   '44_o_1_w_3.png'],
#  '12': ['12_o_1_w_1.png',
#   '12_o_1_n_1.png',
#   '12_o_1_w_4.png',
#   '12_o_1_w_5.png',
#   '12_o_1_n_6.png',
#   '12_o_1_w_8.png',
#   '12_o_1_w_2.png',
#   '12_o_1_w_6.png',
#   '12_o_1_n_4.png',
#   '12_o_1_n_7.png',
#   '12_o_1_n_3.png',
#   '12_o_1_w_7.png',
#   '12_o_1_n_8.png',
#   '12_o_1_n_2.png',
#   '12_o_1_w_3.png',
#   '12_o_1_n_5.png'],
#  '4': ['4_o_1_n_5.png',
#   '4_o_1_n_2.png',
#   '4_o_1_n_6.png',
#   '4_o_1_w_1.png',
#   '4_o_1_w_7.png',
#   '4_o_1_w_4.png',
#   '4_o_1_w_3.png',
#   '4_o_1_n_7.png',
#   '4_o_1_w_6.png',
#   '4_o_1_w_2.png',
#   '4_o_1_n_8.png',
#   '4_o_1_w_8.png',
#   '4_o_1_n_4.png',
#   '4_o_1_n_3.png',
#   '4_o_1_w_5.png',
#   '4_o_1_n_1.png'],
#  '64': ['64_o_1_w_5.png',
#   '64_o_1_n_5.png',
#   '64_o_1_n_2.png',
#   '64_o_1_n_6.png',
#   '64_o_1_w_4.png',
#   '64_o_1_w_2.png',
#   '64_o_1_n_8.png',
#   '64_o_1_w_3.png',
#   '64_o_1_n_3.png',
#   '64_o_1_w_7.png',
#   '64_o_1_w_1.png',
#   '64_o_1_w_8.png',
#   '64_o_1_n_1.png',
#   '64_o_1_w_6.png',
#   '64_o_1_n_4.png',
#   '64_o_1_n_7.png'],
#  '26': ['26_o_1_w_4.png',
#   '26_o_1_n_2.png',
#   '26_o_1_w_7.png',
#   '26_o_1_n_6.png',
#   '26_o_1_w_5.png',
#   '26_o_1_n_7.png',
#   '26_o_1_w_8.png',
#   '26_o_1_w_1.png',
#   '26_o_1_n_8.png',
#   '26_o_1_n_1.png',
#   '26_o_1_n_3.png',
#   '26_o_1_n_5.png',
#   '26_o_1_w_2.png',
#   '26_o_1_w_6.png',
#   '26_o_1_w_3.png',
#   '26_o_1_n_4.png'],
#  '37': ['37_o_1_w_4.png',
#   '37_o_1_n_5.png',
#   '37_o_1_n_2.png',
#   '37_o_1_w_1.png',
#   '37_o_1_w_7.png',
#   '37_o_1_n_4.png',
#   '37_o_1_w_3.png',
#   '37_o_1_w_8.png',
#   '37_o_1_n_8.png',
#   '37_o_1_w_6.png',
#   '37_o_1_n_1.png',
#   '37_o_1_n_3.png',
#   '37_o_1_n_7.png',
#   '37_o_1_n_6.png',
#   '37_o_1_w_5.png',
#   '37_o_1_w_2.png'],
#  '48': ['48_o_1_w_1.png',
#   '48_o_1_w_3.png',
#   '48_o_1_n_8.png',
#   '48_o_1_n_4.png',
#   '48_o_1_n_5.png',
#   '48_o_1_w_6.png',
#   '48_o_1_w_4.png',
#   '48_o_1_w_8.png',
#   '48_o_1_n_3.png',
#   '48_o_1_w_2.png',
#   '48_o_1_w_7.png',
#   '48_o_1_n_7.png',
#   '48_o_1_n_1.png',
#   '48_o_1_n_2.png',
#   '48_o_1_w_5.png',
#   '48_o_1_n_6.png'],
#  '32': ['32_o_1_w_1.png',
#   '32_o_1_w_4.png',
#   '32_o_1_n_2.png',
#   '32_o_1_n_3.png',
#   '32_o_1_w_5.png',
#   '32_o_1_w_2.png',
#   '32_o_1_n_1.png',
#   '32_o_1_n_6.png',
#   '32_o_1_n_8.png',
#   '32_o_1_w_6.png',
#   '32_o_1_w_8.png',
#   '32_o_1_n_4.png',
#   '32_o_1_n_5.png',
#   '32_o_1_w_3.png',
#   '32_o_1_w_7.png',
#   '32_o_1_n_7.png'],
#  '2': ['2_o_1_n_5.png',
#   '2_o_1_w_5.png',
#   '2_o_1_w_6.png',
#   '2_o_1_n_6.png',
#   '2_o_1_n_3.png',
#   '2_o_1_n_2.png',
#   '2_o_1_w_7.png',
#   '2_o_1_n_1.png',
#   '2_o_1_n_7.png',
#   '2_o_1_w_1.png',
#   '2_o_1_n_8.png',
#   '2_o_1_n_4.png',
#   '2_o_1_w_8.png',
#   '2_o_1_w_3.png',
#   '2_o_1_w_4.png',
#   '2_o_1_w_2.png'],
#  '14': ['14_o_1_n_6.png',
#   '14_o_1_w_3.png',
#   '14_o_1_n_1.png',
#   '14_o_1_w_1.png',
#   '14_o_1_n_2.png',
#   '14_o_1_n_3.png',
#   '14_o_1_w_5.png',
#   '14_o_1_n_8.png',
#   '14_o_1_w_6.png',
#   '14_o_1_n_7.png',
#   '14_o_1_w_8.png',
#   '14_o_1_n_4.png',
#   '14_o_1_w_7.png',
#   '14_o_1_n_5.png',
#   '14_o_1_w_2.png',
#   '14_o_1_w_4.png'],
#  '27': ['27_o_1_n_5.png',
#   '27_o_1_w_1.png',
#   '27_o_1_w_4.png',
#   '27_o_1_n_4.png',
#   '27_o_1_n_2.png',
#   '27_o_1_n_1.png',
#   '27_o_1_w_7.png',
#   '27_o_1_w_5.png',
#   '27_o_1_n_3.png',
#   '27_o_1_w_6.png',
#   '27_o_1_n_8.png',
#   '27_o_1_n_6.png',
#   '27_o_1_w_3.png',
#   '27_o_1_w_8.png',
#   '27_o_1_n_7.png',
#   '27_o_1_w_2.png'],
#  '62': ['62_o_1_w_7.png',
#   '62_o_1_w_2.png',
#   '62_o_1_n_3.png',
#   '62_o_1_n_2.png',
#   '62_o_1_w_3.png',
#   '62_o_1_w_5.png',
#   '62_o_1_n_6.png',
#   '62_o_1_n_5.png',
#   '62_o_1_w_4.png',
#   '62_o_1_w_8.png',
#   '62_o_1_w_1.png',
#   '62_o_1_n_4.png',
#   '62_o_1_n_1.png',
#   '62_o_1_n_7.png',
#   '62_o_1_n_8.png',
#   '62_o_1_w_6.png'],
#  '3': ['3_o_1_w_1.png',
#   '3_o_1_w_3.png',
#   '3_o_1_w_4.png',
#   '3_o_1_w_6.png',
#   '3_o_1_n_2.png',
#   '3_o_1_n_7.png',
#   '3_o_1_n_3.png',
#   '3_o_1_n_8.png',
#   '3_o_1_n_1.png',
#   '3_o_1_n_6.png',
#   '3_o_1_n_5.png',
#   '3_o_1_n_4.png',
#   '3_o_1_w_2.png',
#   '3_o_1_w_5.png',
#   '3_o_1_w_7.png',
#   '3_o_1_w_8.png'],
#  '24': ['24_o_1_n_2.png',
#   '24_o_1_n_7.png',
#   '24_o_1_w_2.png',
#   '24_o_1_n_3.png',
#   '24_o_1_n_5.png',
#   '24_o_1_n_6.png',
#   '24_o_1_w_5.png',
#   '24_o_1_n_1.png',
#   '24_o_1_w_4.png',
#   '24_o_1_w_3.png',
#   '24_o_1_w_7.png',
#   '24_o_1_n_4.png',
#   '24_o_1_w_6.png',
#   '24_o_1_w_1.png',
#   '24_o_1_n_8.png',
#   '24_o_1_w_8.png'],
#  '61': ['61_o_1_n_6.png',
#   '61_o_1_n_8.png',
#   '61_o_1_w_7.png',
#   '61_o_1_n_3.png',
#   '61_o_1_n_1.png',
#   '61_o_1_n_2.png',
#   '61_o_1_w_5.png',
#   '61_o_1_w_3.png',
#   '61_o_1_w_1.png',
#   '61_o_1_n_4.png',
#   '61_o_1_w_4.png',
#   '61_o_1_w_8.png',
#   '61_o_1_n_7.png',
#   '61_o_1_w_6.png',
#   '61_o_1_w_2.png',
#   '61_o_1_n_5.png'],
#  '34': ['34_o_1_w_3.png',
#   '34_o_1_n_5.png',
#   '34_o_1_w_4.png',
#   '34_o_1_w_7.png',
#   '34_o_1_w_1.png',
#   '34_o_1_w_6.png',
#   '34_o_1_n_8.png',
#   '34_o_1_n_2.png',
#   '34_o_1_n_4.png',
#   '34_o_1_n_1.png',
#   '34_o_1_n_3.png',
#   '34_o_1_w_8.png',
#   '34_o_1_w_5.png',
#   '34_o_1_w_2.png',
#   '34_o_1_n_6.png',
#   '34_o_1_n_7.png'],
#  '41': ['41_o_1_n_3.png',
#   '41_o_1_n_6.png',
#   '41_o_1_n_4.png',
#   '41_o_1_w_4.png',
#   '41_o_1_n_2.png',
#   '41_o_1_n_1.png',
#   '41_o_1_w_5.png',
#   '41_o_1_n_7.png',
#   '41_o_1_w_6.png',
#   '41_o_1_w_7.png',
#   '41_o_1_n_5.png',
#   '41_o_1_n_8.png',
#   '41_o_1_w_3.png',
#   '41_o_1_w_1.png',
#   '41_o_1_w_8.png',
#   '41_o_1_w_2.png'],
#  '28': ['28_o_1_n_4.png',
#   '28_o_1_n_7.png',
#   '28_o_1_w_5.png',
#   '28_o_1_w_2.png',
#   '28_o_1_w_4.png',
#   '28_o_1_n_6.png',
#   '28_o_1_n_5.png',
#   '28_o_1_w_1.png',
#   '28_o_1_n_2.png',
#   '28_o_1_n_1.png',
#   '28_o_1_w_3.png',
#   '28_o_1_w_8.png',
#   '28_o_1_n_3.png',
#   '28_o_1_w_7.png',
#   '28_o_1_w_6.png',
#   '28_o_1_n_8.png'],
#  '50': ['50_o_1_w_2.png',
#   '50_o_1_w_4.png',
#   '50_o_1_w_3.png',
#   '50_o_1_n_2.png',
#   '50_o_1_w_8.png',
#   '50_o_1_n_1.png',
#   '50_o_1_w_1.png',
#   '50_o_1_w_6.png',
#   '50_o_1_n_7.png',
#   '50_o_1_w_5.png',
#   '50_o_1_n_8.png',
#   '50_o_1_n_6.png',
#   '50_o_1_n_3.png',
#   '50_o_1_n_5.png',
#   '50_o_1_n_4.png',
#   '50_o_1_w_7.png'],
#  '6': ['6_o_1_n_5.png',
#   '6_o_1_n_6.png',
#   '6_o_1_n_3.png',
#   '6_o_1_n_8.png',
#   '6_o_1_w_2.png',
#   '6_o_1_n_2.png',
#   '6_o_1_w_3.png',
#   '6_o_1_n_7.png',
#   '6_o_1_n_1.png',
#   '6_o_1_w_5.png',
#   '6_o_1_w_4.png',
#   '6_o_1_w_8.png',
#   '6_o_1_w_1.png',
#   '6_o_1_n_4.png',
#   '6_o_1_w_6.png',
#   '6_o_1_w_7.png'],
#  '42': ['42_o_1_w_8.png',
#   '42_o_1_n_2.png',
#   '42_o_1_w_1.png',
#   '42_o_1_n_1.png',
#   '42_o_1_w_3.png',
#   '42_o_1_n_7.png',
#   '42_o_1_n_4.png',
#   '42_o_1_w_6.png',
#   '42_o_1_n_3.png',
#   '42_o_1_n_8.png',
#   '42_o_1_w_7.png',
#   '42_o_1_w_4.png',
#   '42_o_1_w_5.png',
#   '42_o_1_n_5.png',
#   '42_o_1_n_6.png',
#   '42_o_1_w_2.png'],
#  '55': ['55_o_1_w_3.png',
#   '55_o_1_w_5.png',
#   '55_o_1_w_8.png',
#   '55_o_1_w_2.png',
#   '55_o_1_n_5.png',
#   '55_o_1_w_4.png',
#   '55_o_1_w_7.png',
#   '55_o_1_w_1.png',
#   '55_o_1_n_7.png',
#   '55_o_1_n_6.png',
#   '55_o_1_w_6.png',
#   '55_o_1_n_1.png',
#   '55_o_1_n_3.png',
#   '55_o_1_n_2.png',
#   '55_o_1_n_4.png',
#   '55_o_1_n_8.png'],
#  '49': ['49_o_1_w_4.png',
#   '49_o_1_n_2.png',
#   '49_o_1_n_5.png',
#   '49_o_1_w_8.png',
#   '49_o_1_w_6.png',
#   '49_o_1_w_3.png',
#   '49_o_1_n_8.png',
#   '49_o_1_w_2.png',
#   '49_o_1_w_5.png',
#   '49_o_1_n_7.png',
#   '49_o_1_n_6.png',
#   '49_o_1_n_1.png',
#   '49_o_1_n_3.png',
#   '49_o_1_w_7.png',
#   '49_o_1_n_4.png',
#   '49_o_1_w_1.png'],
#  '51': ['51_o_1_w_5.png',
#   '51_o_1_n_6.png',
#   '51_o_1_n_7.png',
#   '51_o_1_w_6.png',
#   '51_o_1_n_5.png',
#   '51_o_1_w_2.png',
#   '51_o_1_w_4.png',
#   '51_o_1_w_3.png',
#   '51_o_1_n_3.png',
#   '51_o_1_w_1.png',
#   '51_o_1_n_2.png',
#   '51_o_1_w_8.png',
#   '51_o_1_n_4.png',
#   '51_o_1_n_1.png',
#   '51_o_1_w_7.png',
#   '51_o_1_n_8.png'],
#  '19': ['19_o_1_n_4.png',
#   '19_o_1_n_7.png',
#   '19_o_1_w_4.png',
#   '19_o_1_n_8.png',
#   '19_o_1_w_3.png',
#   '19_o_1_w_8.png',
#   '19_o_1_n_5.png',
#   '19_o_1_n_3.png',
#   '19_o_1_w_6.png',
#   '19_o_1_w_2.png',
#   '19_o_1_w_1.png',
#   '19_o_1_n_2.png',
#   '19_o_1_n_1.png',
#   '19_o_1_w_5.png',
#   '19_o_1_n_6.png',
#   '19_o_1_w_7.png'],
#  '9': ['9_o_1_w_3.png',
#   '9_o_1_w_7.png',
#   '9_o_1_n_1.png',
#   '9_o_1_w_4.png',
#   '9_o_1_n_7.png',
#   '9_o_1_n_4.png',
#   '9_o_1_w_8.png',
#   '9_o_1_w_1.png',
#   '9_o_1_n_6.png',
#   '9_o_1_w_6.png',
#   '9_o_1_n_8.png',
#   '9_o_1_n_3.png',
#   '9_o_1_n_2.png',
#   '9_o_1_w_5.png',
#   '9_o_1_n_5.png',
#   '9_o_1_w_2.png'],
#  '56': ['56_o_1_n_1.png',
#   '56_o_1_w_7.png',
#   '56_o_1_n_5.png',
#   '56_o_1_w_4.png',
#   '56_o_1_n_6.png',
#   '56_o_1_w_6.png',
#   '56_o_1_n_7.png',
#   '56_o_1_w_5.png',
#   '56_o_1_n_8.png',
#   '56_o_1_w_3.png',
#   '56_o_1_w_2.png',
#   '56_o_1_w_8.png',
#   '56_o_1_n_4.png',
#   '56_o_1_n_2.png',
#   '56_o_1_n_3.png',
#   '56_o_1_w_1.png'],
#  '36': ['36_o_1_w_1.png',
#   '36_o_1_n_2.png',
#   '36_o_1_n_5.png',
#   '36_o_1_n_3.png',
#   '36_o_1_w_4.png',
#   '36_o_1_n_4.png',
#   '36_o_1_n_8.png',
#   '36_o_1_w_7.png',
#   '36_o_1_w_6.png',
#   '36_o_1_w_2.png',
#   '36_o_1_w_3.png',
#   '36_o_1_w_8.png',
#   '36_o_1_n_7.png',
#   '36_o_1_n_1.png',
#   '36_o_1_n_6.png',
#   '36_o_1_w_5.png'],
#  '22': ['22_o_1_w_3.png',
#   '22_o_1_n_4.png',
#   '22_o_1_n_7.png',
#   '22_o_1_w_6.png',
#   '22_o_1_w_8.png',
#   '22_o_1_n_2.png',
#   '22_o_1_n_1.png',
#   '22_o_1_n_8.png',
#   '22_o_1_w_5.png',
#   '22_o_1_n_6.png',
#   '22_o_1_n_3.png',
#   '22_o_1_w_7.png',
#   '22_o_1_w_4.png',
#   '22_o_1_w_2.png',
#   '22_o_1_w_1.png',
#   '22_o_1_n_5.png'],
#  '5': ['5_o_1_n_3.png',
#   '5_o_1_w_7.png',
#   '5_o_1_n_2.png',
#   '5_o_1_n_5.png',
#   '5_o_1_w_4.png',
#   '5_o_1_w_2.png',
#   '5_o_1_n_8.png',
#   '5_o_1_w_1.png',
#   '5_o_1_w_3.png',
#   '5_o_1_n_6.png',
#   '5_o_1_n_7.png',
#   '5_o_1_w_8.png',
#   '5_o_1_n_4.png',
#   '5_o_1_w_6.png',
#   '5_o_1_n_1.png',
#   '5_o_1_w_5.png'],
#  '30': ['30_o_1_w_2.png',
#   '30_o_1_n_3.png',
#   '30_o_1_w_5.png',
#   '30_o_1_n_7.png',
#   '30_o_1_n_5.png',
#   '30_o_1_w_8.png',
#   '30_o_1_n_2.png',
#   '30_o_1_n_4.png',
#   '30_o_1_w_6.png',
#   '30_o_1_w_4.png',
#   '30_o_1_n_6.png',
#   '30_o_1_w_7.png',
#   '30_o_1_n_1.png',
#   '30_o_1_n_8.png',
#   '30_o_1_w_3.png',
#   '30_o_1_w_1.png'],
#  '43': ['43_o_1_w_4.png',
#   '43_o_1_w_5.png',
#   '43_o_1_n_6.png',
#   '43_o_1_w_1.png',
#   '43_o_1_n_7.png',
#   '43_o_1_w_6.png',
#   '43_o_1_n_3.png',
#   '43_o_1_n_4.png',
#   '43_o_1_n_1.png',
#   '43_o_1_w_3.png',
#   '43_o_1_w_7.png',
#   '43_o_1_n_8.png',
#   '43_o_1_w_8.png',
#   '43_o_1_n_2.png',
#   '43_o_1_w_2.png',
#   '43_o_1_n_5.png'],
#  '53': ['53_o_1_w_6.png',
#   '53_o_1_n_7.png',
#   '53_o_1_n_5.png',
#   '53_o_1_w_2.png',
#   '53_o_1_n_8.png',
#   '53_o_1_n_1.png',
#   '53_o_1_w_1.png',
#   '53_o_1_w_7.png',
#   '53_o_1_n_4.png',
#   '53_o_1_w_3.png',
#   '53_o_1_n_6.png',
#   '53_o_1_n_2.png',
#   '53_o_1_w_5.png',
#   '53_o_1_w_8.png',
#   '53_o_1_n_3.png',
#   '53_o_1_w_4.png'],
#  '58': ['58_o_1_n_4.png',
#   '58_o_1_w_5.png',
#   '58_o_1_n_1.png',
#   '58_o_1_w_1.png',
#   '58_o_1_w_3.png',
#   '58_o_1_n_6.png',
#   '58_o_1_n_3.png',
#   '58_o_1_w_8.png',
#   '58_o_1_n_5.png',
#   '58_o_1_w_2.png',
#   '58_o_1_n_7.png',
#   '58_o_1_w_4.png',
#   '58_o_1_w_6.png',
#   '58_o_1_w_7.png',
#   '58_o_1_n_8.png',
#   '58_o_1_n_2.png'],
#  '54': ['54_o_1_w_7.png',
#   '54_o_1_w_4.png',
#   '54_o_1_n_5.png',
#   '54_o_1_n_4.png',
#   '54_o_1_n_6.png',
#   '54_o_1_n_1.png',
#   '54_o_1_n_2.png',
#   '54_o_1_w_6.png',
#   '54_o_1_w_8.png',
#   '54_o_1_w_1.png',
#   '54_o_1_w_2.png',
#   '54_o_1_n_8.png',
#   '54_o_1_n_7.png',
#   '54_o_1_n_3.png',
#   '54_o_1_w_5.png',
#   '54_o_1_w_3.png'],
#  '63': ['63_o_1_n_6.png',
#   '63_o_1_w_6.png',
#   '63_o_1_w_1.png',
#   '63_o_1_w_7.png',
#   '63_o_1_n_3.png',
#   '63_o_1_n_1.png',
#   '63_o_1_w_2.png',
#   '63_o_1_n_7.png',
#   '63_o_1_n_4.png',
#   '63_o_1_w_8.png',
#   '63_o_1_n_5.png',
#   '63_o_1_n_2.png',
#   '63_o_1_w_5.png',
#   '63_o_1_n_8.png',
#   '63_o_1_w_3.png',
#   '63_o_1_w_4.png'],
#  '39': ['39_o_1_w_7.png',
#   '39_o_1_w_6.png',
#   '39_o_1_w_5.png',
#   '39_o_1_n_1.png',
#   '39_o_1_n_3.png',
#   '39_o_1_n_7.png',
#   '39_o_1_n_6.png',
#   '39_o_1_w_1.png',
#   '39_o_1_n_8.png',
#   '39_o_1_w_4.png',
#   '39_o_1_w_8.png',
#   '39_o_1_n_4.png',
#   '39_o_1_w_2.png',
#   '39_o_1_n_2.png',
#   '39_o_1_w_3.png',
#   '39_o_1_n_5.png'],
#  '33': ['33_o_1_w_1.png',
#   '33_o_1_n_4.png',
#   '33_o_1_n_6.png',
#   '33_o_1_w_2.png',
#   '33_o_1_w_8.png',
#   '33_o_1_n_5.png',
#   '33_o_1_w_7.png',
#   '33_o_1_w_3.png',
#   '33_o_1_w_4.png',
#   '33_o_1_w_5.png',
#   '33_o_1_n_2.png',
#   '33_o_1_n_7.png',
#   '33_o_1_w_6.png',
#   '33_o_1_n_8.png',
#   '33_o_1_n_1.png',
#   '33_o_1_n_3.png'],
#  '20': ['20_o_1_n_3.png',
#   '20_o_1_w_7.png',
#   '20_o_1_n_6.png',
#   '20_o_1_w_4.png',
#   '20_o_1_n_2.png',
#   '20_o_1_w_3.png',
#   '20_o_1_n_7.png',
#   '20_o_1_n_4.png',
#   '20_o_1_w_5.png',
#   '20_o_1_w_2.png',
#   '20_o_1_w_8.png',
#   '20_o_1_w_6.png',
#   '20_o_1_n_1.png',
#   '20_o_1_w_1.png',
#   '20_o_1_n_5.png',
#   '20_o_1_n_8.png']}

# %%
# train (70%) and test (30%) split
train = {}
test = {}

for id in ids_to_file:
    naturals = [x for x in ids_to_file[id] if '_n_' in x]
    whites = [x for x in ids_to_file[id] if '_n_' not in x]

    train_naturals = np.random.choice(naturals, 6, replace=False) # 70% of the natural images will be used for training
    train_whites = np.random.choice(whites, 5, replace=False) # 70% of the white images will be used for training

    # concatenate the two lists
    train[id] = list(np.concatenate((train_naturals, train_whites)))

    # the remaining images will be used for testing
    test_naturals = [x for x in naturals if x not in train_naturals]
    test_whites = [x for x in whites if x not in train_whites]

    test[id] = list(np.concatenate((test_naturals, test_whites)))

print(sum([len(x) for x in train.values()]))
print(sum([len(x) for x in test.values()]))
# Out:
# 704
# 320

# %%
# now create the subfolders "train" and "test" inside "DatasetFinal" and move the images in the correct folder

# create the subfolders
os.mkdir("DatasetFinal")
os.mkdir("DatasetFinal/train")
os.mkdir("DatasetFinal/test")

for id in train:
    for img in train[id]:
        shutil.copy("LivescanUnified/" + img, "DatasetFinal/train/" + img)

for id in test:
    for img in test[id]:
        shutil.copy("LivescanUnified/" + img, "DatasetFinal/test/" + img)

# %% [markdown]
# ## 3. Split both train and test sets in probe and gallery
# For the test set, this split is repeated 5 times in order to have statistically reliable scores.

# %%
# first, rename the images in the Dataset folder

for id in train:

    new_names = []
    for old_name in train[id]:
        infos = old_name.split('_')
        new_name = infos[0] + '_' + infos[3] + '_' + infos[4]

        new_names.append(new_name)
        os.rename("DatasetFinal/train/" + old_name, "DatasetFinal/train/" + new_name)

    train[id] = new_names


for id in test:

    new_names = []
    for old_name in test[id]:
        infos = old_name.split('_')
        new_name = infos[0] + '_' + infos[3] + '_' + infos[4]

        new_names.append(new_name)
        os.rename("DatasetFinal/test/" + old_name, "DatasetFinal/test/" + new_name)

    test[id] = new_names

train
# Out:
# {'10': ['10_n_1.png',
#   '10_n_2.png',
#   '10_n_7.png',
#   '10_n_6.png',
#   '10_n_4.png',
#   '10_n_3.png',
#   '10_w_1.png',
#   '10_w_2.png',
#   '10_w_8.png',
#   '10_w_5.png',
#   '10_w_4.png'],
#  '18': ['18_n_7.png',
#   '18_n_2.png',
#   '18_n_6.png',
#   '18_n_1.png',
#   '18_n_3.png',
#   '18_n_4.png',
#   '18_w_7.png',
#   '18_w_2.png',
#   '18_w_6.png',
#   '18_w_4.png',
#   '18_w_8.png'],
#  '35': ['35_n_2.png',
#   '35_n_5.png',
#   '35_n_7.png',
#   '35_n_4.png',
#   '35_n_3.png',
#   '35_n_6.png',
#   '35_w_7.png',
#   '35_w_8.png',
#   '35_w_2.png',
#   '35_w_3.png',
#   '35_w_6.png'],
#  '1': ['1_n_2.png',
#   '1_n_4.png',
#   '1_n_1.png',
#   '1_n_5.png',
#   '1_n_6.png',
#   '1_n_8.png',
#   '1_w_3.png',
#   '1_w_7.png',
#   '1_w_2.png',
#   '1_w_8.png',
#   '1_w_6.png'],
#  '23': ['23_n_5.png',
#   '23_n_1.png',
#   '23_n_2.png',
#   '23_n_8.png',
#   '23_n_3.png',
#   '23_n_4.png',
#   '23_w_2.png',
#   '23_w_8.png',
#   '23_w_5.png',
#   '23_w_3.png',
#   '23_w_1.png'],
#  '57': ['57_n_3.png',
#   '57_n_8.png',
#   '57_n_1.png',
#   '57_n_4.png',
#   '57_n_7.png',
#   '57_n_2.png',
#   '57_w_6.png',
#   '57_w_4.png',
#   '57_w_8.png',
#   '57_w_2.png',
#   '57_w_1.png'],
#  '8': ['8_n_2.png',
#   '8_n_4.png',
#   '8_n_7.png',
#   '8_n_3.png',
#   '8_n_8.png',
#   '8_n_5.png',
#   '8_w_7.png',
#   '8_w_6.png',
#   '8_w_1.png',
#   '8_w_8.png',
#   '8_w_4.png'],
#  '16': ['16_n_1.png',
#   '16_n_7.png',
#   '16_n_3.png',
#   '16_n_8.png',
#   '16_n_6.png',
#   '16_n_2.png',
#   '16_w_7.png',
#   '16_w_3.png',
#   '16_w_5.png',
#   '16_w_6.png',
#   '16_w_1.png'],
#  '45': ['45_n_6.png',
#   '45_n_2.png',
#   '45_n_8.png',
#   '45_n_5.png',
#   '45_n_4.png',
#   '45_n_3.png',
#   '45_w_4.png',
#   '45_w_2.png',
#   '45_w_3.png',
#   '45_w_5.png',
#   '45_w_6.png'],
#  '25': ['25_n_2.png',
#   '25_n_7.png',
#   '25_n_1.png',
#   '25_n_3.png',
#   '25_n_8.png',
#   '25_n_4.png',
#   '25_w_6.png',
#   '25_w_7.png',
#   '25_w_5.png',
#   '25_w_4.png',
#   '25_w_1.png'],
#  '46': ['46_n_4.png',
#   '46_n_5.png',
#   '46_n_1.png',
#   '46_n_6.png',
#   '46_n_7.png',
#   '46_n_2.png',
#   '46_w_6.png',
#   '46_w_7.png',
#   '46_w_5.png',
#   '46_w_8.png',
#   '46_w_3.png'],
#  '15': ['15_n_7.png',
#   '15_n_2.png',
#   '15_n_4.png',
#   '15_n_3.png',
#   '15_n_8.png',
#   '15_n_6.png',
#   '15_w_4.png',
#   '15_w_3.png',
#   '15_w_5.png',
#   '15_w_2.png',
#   '15_w_8.png'],
#  '31': ['31_n_7.png',
#   '31_n_4.png',
#   '31_n_8.png',
#   '31_n_3.png',
#   '31_n_2.png',
#   '31_n_1.png',
#   '31_w_4.png',
#   '31_w_8.png',
#   '31_w_6.png',
#   '31_w_2.png',
#   '31_w_1.png'],
#  '47': ['47_n_1.png',
#   '47_n_6.png',
#   '47_n_7.png',
#   '47_n_5.png',
#   '47_n_2.png',
#   '47_n_8.png',
#   '47_w_7.png',
#   '47_w_4.png',
#   '47_w_6.png',
#   '47_w_1.png',
#   '47_w_3.png'],
#  '7': ['7_n_5.png',
#   '7_n_7.png',
#   '7_n_2.png',
#   '7_n_4.png',
#   '7_n_8.png',
#   '7_n_3.png',
#   '7_w_3.png',
#   '7_w_5.png',
#   '7_w_6.png',
#   '7_w_2.png',
#   '7_w_4.png'],
#  '59': ['59_n_1.png',
#   '59_n_3.png',
#   '59_n_2.png',
#   '59_n_8.png',
#   '59_n_4.png',
#   '59_n_6.png',
#   '59_w_3.png',
#   '59_w_7.png',
#   '59_w_8.png',
#   '59_w_2.png',
#   '59_w_5.png'],
#  '13': ['13_n_3.png',
#   '13_n_5.png',
#   '13_n_4.png',
#   '13_n_1.png',
#   '13_n_6.png',
#   '13_n_7.png',
#   '13_w_3.png',
#   '13_w_4.png',
#   '13_w_7.png',
#   '13_w_6.png',
#   '13_w_8.png'],
#  '21': ['21_n_8.png',
#   '21_n_4.png',
#   '21_n_1.png',
#   '21_n_3.png',
#   '21_n_2.png',
#   '21_n_6.png',
#   '21_w_2.png',
#   '21_w_3.png',
#   '21_w_1.png',
#   '21_w_6.png',
#   '21_w_7.png'],
#  '29': ['29_n_4.png',
#   '29_n_1.png',
#   '29_n_6.png',
#   '29_n_8.png',
#   '29_n_5.png',
#   '29_n_3.png',
#   '29_w_8.png',
#   '29_w_7.png',
#   '29_w_6.png',
#   '29_w_3.png',
#   '29_w_4.png'],
#  '38': ['38_n_7.png',
#   '38_n_2.png',
#   '38_n_5.png',
#   '38_n_4.png',
#   '38_n_3.png',
#   '38_n_6.png',
#   '38_w_7.png',
#   '38_w_5.png',
#   '38_w_4.png',
#   '38_w_6.png',
#   '38_w_3.png'],
#  '17': ['17_n_2.png',
#   '17_n_1.png',
#   '17_n_7.png',
#   '17_n_8.png',
#   '17_n_3.png',
#   '17_n_4.png',
#   '17_w_3.png',
#   '17_w_8.png',
#   '17_w_7.png',
#   '17_w_1.png',
#   '17_w_4.png'],
#  '60': ['60_n_3.png',
#   '60_n_5.png',
#   '60_n_6.png',
#   '60_n_7.png',
#   '60_n_8.png',
#   '60_n_2.png',
#   '60_w_6.png',
#   '60_w_7.png',
#   '60_w_2.png',
#   '60_w_3.png',
#   '60_w_4.png'],
#  '11': ['11_n_3.png',
#   '11_n_7.png',
#   '11_n_1.png',
#   '11_n_4.png',
#   '11_n_6.png',
#   '11_n_2.png',
#   '11_w_3.png',
#   '11_w_7.png',
#   '11_w_8.png',
#   '11_w_5.png',
#   '11_w_2.png'],
#  '52': ['52_n_5.png',
#   '52_n_1.png',
#   '52_n_4.png',
#   '52_n_3.png',
#   '52_n_2.png',
#   '52_n_6.png',
#   '52_w_7.png',
#   '52_w_3.png',
#   '52_w_8.png',
#   '52_w_6.png',
#   '52_w_5.png'],
#  '40': ['40_n_6.png',
#   '40_n_1.png',
#   '40_n_7.png',
#   '40_n_3.png',
#   '40_n_8.png',
#   '40_n_4.png',
#   '40_w_1.png',
#   '40_w_5.png',
#   '40_w_7.png',
#   '40_w_3.png',
#   '40_w_8.png'],
#  '44': ['44_n_2.png',
#   '44_n_3.png',
#   '44_n_6.png',
#   '44_n_4.png',
#   '44_n_7.png',
#   '44_n_1.png',
#   '44_w_1.png',
#   '44_w_8.png',
#   '44_w_3.png',
#   '44_w_4.png',
#   '44_w_6.png'],
#  '12': ['12_n_7.png',
#   '12_n_8.png',
#   '12_n_3.png',
#   '12_n_5.png',
#   '12_n_4.png',
#   '12_n_6.png',
#   '12_w_5.png',
#   '12_w_8.png',
#   '12_w_7.png',
#   '12_w_1.png',
#   '12_w_6.png'],
#  '4': ['4_n_5.png',
#   '4_n_4.png',
#   '4_n_7.png',
#   '4_n_3.png',
#   '4_n_2.png',
#   '4_n_6.png',
#   '4_w_2.png',
#   '4_w_4.png',
#   '4_w_7.png',
#   '4_w_6.png',
#   '4_w_8.png'],
#  '64': ['64_n_7.png',
#   '64_n_5.png',
#   '64_n_6.png',
#   '64_n_3.png',
#   '64_n_8.png',
#   '64_n_4.png',
#   '64_w_8.png',
#   '64_w_4.png',
#   '64_w_3.png',
#   '64_w_5.png',
#   '64_w_2.png'],
#  '26': ['26_n_6.png',
#   '26_n_7.png',
#   '26_n_1.png',
#   '26_n_5.png',
#   '26_n_3.png',
#   '26_n_4.png',
#   '26_w_8.png',
#   '26_w_6.png',
#   '26_w_7.png',
#   '26_w_4.png',
#   '26_w_2.png'],
#  '37': ['37_n_8.png',
#   '37_n_3.png',
#   '37_n_1.png',
#   '37_n_7.png',
#   '37_n_6.png',
#   '37_n_4.png',
#   '37_w_1.png',
#   '37_w_6.png',
#   '37_w_7.png',
#   '37_w_3.png',
#   '37_w_4.png'],
#  '48': ['48_n_5.png',
#   '48_n_6.png',
#   '48_n_7.png',
#   '48_n_8.png',
#   '48_n_2.png',
#   '48_n_3.png',
#   '48_w_8.png',
#   '48_w_2.png',
#   '48_w_5.png',
#   '48_w_6.png',
#   '48_w_4.png'],
#  '32': ['32_n_8.png',
#   '32_n_3.png',
#   '32_n_7.png',
#   '32_n_6.png',
#   '32_n_2.png',
#   '32_n_4.png',
#   '32_w_3.png',
#   '32_w_6.png',
#   '32_w_2.png',
#   '32_w_8.png',
#   '32_w_1.png'],
#  '2': ['2_n_7.png',
#   '2_n_1.png',
#   '2_n_6.png',
#   '2_n_4.png',
#   '2_n_2.png',
#   '2_n_8.png',
#   '2_w_7.png',
#   '2_w_5.png',
#   '2_w_6.png',
#   '2_w_8.png',
#   '2_w_1.png'],
#  '14': ['14_n_8.png',
#   '14_n_6.png',
#   '14_n_1.png',
#   '14_n_5.png',
#   '14_n_2.png',
#   '14_n_4.png',
#   '14_w_4.png',
#   '14_w_6.png',
#   '14_w_3.png',
#   '14_w_5.png',
#   '14_w_8.png'],
#  '27': ['27_n_7.png',
#   '27_n_5.png',
#   '27_n_6.png',
#   '27_n_2.png',
#   '27_n_4.png',
#   '27_n_8.png',
#   '27_w_6.png',
#   '27_w_2.png',
#   '27_w_1.png',
#   '27_w_8.png',
#   '27_w_3.png'],
#  '62': ['62_n_3.png',
#   '62_n_7.png',
#   '62_n_4.png',
#   '62_n_1.png',
#   '62_n_6.png',
#   '62_n_5.png',
#   '62_w_5.png',
#   '62_w_3.png',
#   '62_w_2.png',
#   '62_w_4.png',
#   '62_w_8.png'],
#  '3': ['3_n_4.png',
#   '3_n_2.png',
#   '3_n_5.png',
#   '3_n_6.png',
#   '3_n_1.png',
#   '3_n_8.png',
#   '3_w_8.png',
#   '3_w_6.png',
#   '3_w_7.png',
#   '3_w_3.png',
#   '3_w_2.png'],
#  '24': ['24_n_3.png',
#   '24_n_1.png',
#   '24_n_7.png',
#   '24_n_8.png',
#   '24_n_4.png',
#   '24_n_5.png',
#   '24_w_4.png',
#   '24_w_3.png',
#   '24_w_6.png',
#   '24_w_1.png',
#   '24_w_8.png'],
#  '61': ['61_n_1.png',
#   '61_n_5.png',
#   '61_n_8.png',
#   '61_n_6.png',
#   '61_n_3.png',
#   '61_n_4.png',
#   '61_w_4.png',
#   '61_w_1.png',
#   '61_w_5.png',
#   '61_w_6.png',
#   '61_w_2.png'],
#  '34': ['34_n_3.png',
#   '34_n_5.png',
#   '34_n_7.png',
#   '34_n_4.png',
#   '34_n_2.png',
#   '34_n_8.png',
#   '34_w_8.png',
#   '34_w_2.png',
#   '34_w_4.png',
#   '34_w_3.png',
#   '34_w_1.png'],
#  '41': ['41_n_8.png',
#   '41_n_4.png',
#   '41_n_3.png',
#   '41_n_2.png',
#   '41_n_5.png',
#   '41_n_7.png',
#   '41_w_8.png',
#   '41_w_5.png',
#   '41_w_2.png',
#   '41_w_4.png',
#   '41_w_6.png'],
#  '28': ['28_n_1.png',
#   '28_n_4.png',
#   '28_n_3.png',
#   '28_n_7.png',
#   '28_n_2.png',
#   '28_n_6.png',
#   '28_w_4.png',
#   '28_w_8.png',
#   '28_w_7.png',
#   '28_w_5.png',
#   '28_w_1.png'],
#  '50': ['50_n_6.png',
#   '50_n_8.png',
#   '50_n_4.png',
#   '50_n_1.png',
#   '50_n_2.png',
#   '50_n_3.png',
#   '50_w_5.png',
#   '50_w_4.png',
#   '50_w_6.png',
#   '50_w_2.png',
#   '50_w_3.png'],
#  '6': ['6_n_6.png',
#   '6_n_7.png',
#   '6_n_2.png',
#   '6_n_4.png',
#   '6_n_3.png',
#   '6_n_5.png',
#   '6_w_7.png',
#   '6_w_3.png',
#   '6_w_6.png',
#   '6_w_1.png',
#   '6_w_8.png'],
#  '42': ['42_n_1.png',
#   '42_n_8.png',
#   '42_n_7.png',
#   '42_n_5.png',
#   '42_n_3.png',
#   '42_n_6.png',
#   '42_w_5.png',
#   '42_w_3.png',
#   '42_w_6.png',
#   '42_w_7.png',
#   '42_w_4.png'],
#  '55': ['55_n_8.png',
#   '55_n_2.png',
#   '55_n_4.png',
#   '55_n_1.png',
#   '55_n_6.png',
#   '55_n_5.png',
#   '55_w_5.png',
#   '55_w_6.png',
#   '55_w_4.png',
#   '55_w_2.png',
#   '55_w_3.png'],
#  '49': ['49_n_8.png',
#   '49_n_6.png',
#   '49_n_5.png',
#   '49_n_7.png',
#   '49_n_3.png',
#   '49_n_1.png',
#   '49_w_2.png',
#   '49_w_1.png',
#   '49_w_7.png',
#   '49_w_5.png',
#   '49_w_4.png'],
#  '51': ['51_n_8.png',
#   '51_n_6.png',
#   '51_n_7.png',
#   '51_n_4.png',
#   '51_n_5.png',
#   '51_n_3.png',
#   '51_w_6.png',
#   '51_w_5.png',
#   '51_w_8.png',
#   '51_w_4.png',
#   '51_w_1.png'],
#  '19': ['19_n_6.png',
#   '19_n_1.png',
#   '19_n_3.png',
#   '19_n_8.png',
#   '19_n_5.png',
#   '19_n_7.png',
#   '19_w_2.png',
#   '19_w_4.png',
#   '19_w_1.png',
#   '19_w_5.png',
#   '19_w_8.png'],
#  '9': ['9_n_1.png',
#   '9_n_5.png',
#   '9_n_6.png',
#   '9_n_3.png',
#   '9_n_2.png',
#   '9_n_7.png',
#   '9_w_3.png',
#   '9_w_2.png',
#   '9_w_8.png',
#   '9_w_4.png',
#   '9_w_1.png'],
#  '56': ['56_n_7.png',
#   '56_n_8.png',
#   '56_n_5.png',
#   '56_n_6.png',
#   '56_n_1.png',
#   '56_n_2.png',
#   '56_w_6.png',
#   '56_w_4.png',
#   '56_w_8.png',
#   '56_w_3.png',
#   '56_w_1.png'],
#  '36': ['36_n_2.png',
#   '36_n_8.png',
#   '36_n_3.png',
#   '36_n_4.png',
#   '36_n_1.png',
#   '36_n_6.png',
#   '36_w_6.png',
#   '36_w_8.png',
#   '36_w_1.png',
#   '36_w_5.png',
#   '36_w_4.png'],
#  '22': ['22_n_3.png',
#   '22_n_6.png',
#   '22_n_2.png',
#   '22_n_4.png',
#   '22_n_5.png',
#   '22_n_7.png',
#   '22_w_2.png',
#   '22_w_6.png',
#   '22_w_4.png',
#   '22_w_5.png',
#   '22_w_1.png'],
#  '5': ['5_n_5.png',
#   '5_n_3.png',
#   '5_n_4.png',
#   '5_n_8.png',
#   '5_n_7.png',
#   '5_n_1.png',
#   '5_w_5.png',
#   '5_w_6.png',
#   '5_w_7.png',
#   '5_w_8.png',
#   '5_w_2.png'],
#  '30': ['30_n_4.png',
#   '30_n_2.png',
#   '30_n_8.png',
#   '30_n_3.png',
#   '30_n_1.png',
#   '30_n_7.png',
#   '30_w_1.png',
#   '30_w_3.png',
#   '30_w_6.png',
#   '30_w_4.png',
#   '30_w_5.png'],
#  '43': ['43_n_4.png',
#   '43_n_2.png',
#   '43_n_7.png',
#   '43_n_1.png',
#   '43_n_8.png',
#   '43_n_5.png',
#   '43_w_8.png',
#   '43_w_1.png',
#   '43_w_4.png',
#   '43_w_6.png',
#   '43_w_2.png'],
#  '53': ['53_n_4.png',
#   '53_n_5.png',
#   '53_n_2.png',
#   '53_n_3.png',
#   '53_n_8.png',
#   '53_n_6.png',
#   '53_w_8.png',
#   '53_w_6.png',
#   '53_w_3.png',
#   '53_w_7.png',
#   '53_w_1.png'],
#  '58': ['58_n_2.png',
#   '58_n_1.png',
#   '58_n_3.png',
#   '58_n_7.png',
#   '58_n_4.png',
#   '58_n_8.png',
#   '58_w_8.png',
#   '58_w_1.png',
#   '58_w_5.png',
#   '58_w_7.png',
#   '58_w_2.png'],
#  '54': ['54_n_6.png',
#   '54_n_8.png',
#   '54_n_2.png',
#   '54_n_7.png',
#   '54_n_5.png',
#   '54_n_1.png',
#   '54_w_2.png',
#   '54_w_7.png',
#   '54_w_8.png',
#   '54_w_3.png',
#   '54_w_4.png'],
#  '63': ['63_n_6.png',
#   '63_n_3.png',
#   '63_n_5.png',
#   '63_n_2.png',
#   '63_n_4.png',
#   '63_n_8.png',
#   '63_w_2.png',
#   '63_w_5.png',
#   '63_w_3.png',
#   '63_w_6.png',
#   '63_w_1.png'],
#  '39': ['39_n_2.png',
#   '39_n_5.png',
#   '39_n_8.png',
#   '39_n_1.png',
#   '39_n_3.png',
#   '39_n_6.png',
#   '39_w_3.png',
#   '39_w_5.png',
#   '39_w_1.png',
#   '39_w_8.png',
#   '39_w_7.png'],
#  '33': ['33_n_4.png',
#   '33_n_1.png',
#   '33_n_2.png',
#   '33_n_8.png',
#   '33_n_6.png',
#   '33_n_3.png',
#   '33_w_5.png',
#   '33_w_8.png',
#   '33_w_6.png',
#   '33_w_4.png',
#   '33_w_2.png'],
#  '20': ['20_n_7.png',
#   '20_n_3.png',
#   '20_n_8.png',
#   '20_n_4.png',
#   '20_n_6.png',
#   '20_n_1.png',
#   '20_w_8.png',
#   '20_w_3.png',
#   '20_w_1.png',
#   '20_w_6.png',
#   '20_w_4.png']}

# %%
# split train set into probe and gallery
train_probe = {}
train_gallery = {}

for id in train:

    naturals = [x for x in train[id] if '_n_' in x] #6
    whites = [x for x in train[id] if '_n_' not in x] #5

    gallery_naturals = np.random.choice(naturals, 3, replace=False) # half of the natural images will be used for gallery
    gallery_whites = np.random.choice(whites, 3, replace=False) # half of the white images will be used for gallery

    # concatenate the two lists
    train_gallery[id] = list(np.concatenate((gallery_naturals, gallery_whites)))

    # the remaining images will be used for the probe set
    probe_naturals = [x for x in naturals if x not in gallery_naturals]
    probe_whites = [x for x in whites if x not in gallery_whites]

    train_probe[id] = list(np.concatenate((probe_naturals, probe_whites)))

    assert len(train_gallery[id]) == 6 and len(train_probe[id]) == 5, f"ERROR IN PROBE VS GALLERY DIVISION FOR SAMPLE {id}"

print(sum([len(x) for x in train_gallery.values()]) + sum([len(x) for x in train_probe.values()]), "total number of samples in train set")
# Out:
# 704 total number of samples in train set

# %%
# check that there are no duplicates between probe and gallery
print(train_probe["22"])
print(train_gallery["22"])
# Out:
# ['22_n_6.png', '22_n_2.png', '22_n_5.png', '22_w_2.png', '22_w_1.png']
# ['22_n_7.png', '22_n_3.png', '22_n_4.png', '22_w_6.png', '22_w_4.png', '22_w_5.png']

# %%
# dump train_probe and train_gallery in a json file

with open("DatasetFinal/train/probe_gallery.json", "w") as f:
    json.dump({"probe": train_probe, "gallery": train_gallery}, f)

# %%
# now split test set into probe and gallery
to_dump = {}

for i in range(1,6): # make 5 different splits for test reliability
    test_probe = {}
    test_gallery = {}

    for id in test:
        naturals = [x for x in test[id] if '_n_' in x] #2
        whites = [x for x in test[id] if '_n_' not in x] #3

        gallery_naturals = np.random.choice(naturals, 1, replace=False) # half of the natural images will be used for gallery
        gallery_whites = np.random.choice(whites, 2, replace=False) # half of the white images will be used for gallery

        # concatenate the two lists
        test_gallery[id] = list(np.concatenate((gallery_naturals, gallery_whites)))

        # the remaining images will be used for the probe set
        probe_naturals = [x for x in naturals if x not in gallery_naturals]
        probe_whites = [x for x in whites if x not in gallery_whites]

        test_probe[id] = list(np.concatenate((probe_naturals, probe_whites)))

        assert len(test_gallery[id]) == 3 and len(test_probe[id]) == 2, f"ERROR IN PROBE VS GALLERY DIVISION FOR SAMPLE {id}"

    print(sum([len(x) for x in test_gallery.values()]) + sum([len(x) for x in test_probe.values()]), "total number of samples in test set split", i)

    to_dump[i] = {"probe": test_probe, "gallery": test_gallery}

# now dump the 5 splits in a json file
with open("DatasetFinal/test/probe_gallery.json", "w") as f:
    json.dump(to_dump, f)
# Out:
# 320 total number of samples in test set split 1
# 320 total number of samples in test set split 2
# 320 total number of samples in test set split 3
# 320 total number of samples in test set split 4
# 320 total number of samples in test set split 5

# %% [markdown]
# =====================================================================================================================================

# %%
# EXAMPLE ON HOW TO PARSE THE PROBE VS GALLERY DIVISION FOR TRAIN SET

with open("DatasetFinal/train/probe_gallery.json") as json_file:
    data = json.load(json_file)


probe = data["probe"]
gallery = data["gallery"]

print(probe.keys())
print(probe["38"])
print(gallery.keys())
print(gallery["38"])
# Out:
# dict_keys(['10', '18', '35', '1', '23', '57', '8', '16', '45', '25', '46', '15', '31', '47', '7', '59', '13', '21', '29', '38', '17', '60', '11', '52', '40', '44', '12', '4', '64', '26', '37', '48', '32', '2', '14', '27', '62', '3', '24', '61', '34', '41', '28', '50', '6', '42', '55', '49', '51', '19', '9', '56', '36', '22', '5', '30', '43', '53', '58', '54', '63', '39', '33', '20'])
# ['38_n_2.png', '38_n_4.png', '38_n_3.png', '38_w_5.png', '38_w_6.png']
# dict_keys(['10', '18', '35', '1', '23', '57', '8', '16', '45', '25', '46', '15', '31', '47', '7', '59', '13', '21', '29', '38', '17', '60', '11', '52', '40', '44', '12', '4', '64', '26', '37', '48', '32', '2', '14', '27', '62', '3', '24', '61', '34', '41', '28', '50', '6', '42', '55', '49', '51', '19', '9', '56', '36', '22', '5', '30', '43', '53', '58', '54', '63', '39', '33', '20'])
# ['38_n_5.png', '38_n_6.png', '38_n_7.png', '38_w_7.png', '38_w_4.png', '38_w_3.png']

# %%
# EXAMPLE ON HOW TO PARSE THE PROBE VS GALLERY DIVISION FOR TEST SET

with open("DatasetFinal/test/probe_gallery.json") as json_file:
    data = json.load(json_file)

for i in range(1,6):
    # take probe and gallery of the i-th split
    probe = data[str(i)]["probe"]
    gallery = data[str(i)]["gallery"]

    # DO YOUR TESTS HERE
    # ....
    # APPEND YOUR RESULTS TO A LIST

    print(probe.keys())
    print(probe["38"])
    print(gallery.keys())
    print(gallery["38"])
    print()

# PLOT AVERAGE METRICS
# Out:
# dict_keys(['10', '18', '35', '1', '23', '57', '8', '16', '45', '25', '46', '15', '31', '47', '7', '59', '13', '21', '29', '38', '17', '60', '11', '52', '40', '44', '12', '4', '64', '26', '37', '48', '32', '2', '14', '27', '62', '3', '24', '61', '34', '41', '28', '50', '6', '42', '55', '49', '51', '19', '9', '56', '36', '22', '5', '30', '43', '53', '58', '54', '63', '39', '33', '20'])
# ['38_n_1.png', '38_w_2.png']
# dict_keys(['10', '18', '35', '1', '23', '57', '8', '16', '45', '25', '46', '15', '31', '47', '7', '59', '13', '21', '29', '38', '17', '60', '11', '52', '40', '44', '12', '4', '64', '26', '37', '48', '32', '2', '14', '27', '62', '3', '24', '61', '34', '41', '28', '50', '6', '42', '55', '49', '51', '19', '9', '56', '36', '22', '5', '30', '43', '53', '58', '54', '63', '39', '33', '20'])
# ['38_n_8.png', '38_w_8.png', '38_w_1.png']
#
# dict_keys(['10', '18', '35', '1', '23', '57', '8', '16', '45', '25', '46', '15', '31', '47', '7', '59', '13', '21', '29', '38', '17', '60', '11', '52', '40', '44', '12', '4', '64', '26', '37', '48', '32', '2', '14', '27', '62', '3', '24', '61', '34', '41', '28', '50', '6', '42', '55', '49', '51', '19', '9', '56', '36', '22', '5', '30', '43', '53', '58', '54', '63', '39', '33', '20'])
# ['38_n_8.png', '38_w_1.png']
# dict_keys(['10', '18', '35', '1', '23', '57', '8', '16', '45', '25', '46', '15', '31', '47', '7', '59', '13', '21', '29', '38', '17', '60', '11', '52', '40', '44', '12', '4', '64', '26', '37', '48', '32', '2', '14', '27', '62', '3', '24', '61', '34', '41', '28', '50', '6', '42', '55', '49', '51', '19', '9', '56', '36', '22', '5', '30', '43', '53', '58', '54', '63', '39', '33', '20'])
# ['38_n_1.png', '38_w_8.png', '38_w_2.png']
#
# dict_keys(['10', '18', '35', '1', '23', '57', '8', '16', '45', '25', '46', '15', '31', '47', '7', '59', '13', '21', '29', '38', '17', '60', '11', '52', '40', '44', '12', '4', '64', '26', '37', '48', '32', '2', '14', '27', '62', '3', '24', '61', '34', '41', '28', '50', '6', '42', '55', '49', '51', '19', '9', '56', '36', '22', '5', '30', '43', '53', '58', '54', '63', '39', '33', '20'])
# ['38_n_8.png', '38_w_2.png']
# dict_keys(['10', '18', '35', '1', '23', '57', '8', '16', '45', '25', '46', '15', '31', '47', '7', '59', '13', '21', '29', '38', '17', '60', '11', '52', '40', '44', '12', '4', '64', '26', '37', '48', '32', '2', '14', '27', '62', '3', '24', '61', '34', '41', '28', '50', '6', '42', '55', '49', '51', '19', '9', '56', '36', '22', '5', '30', '43', '53', '58', '54', '63', '39', '33', '20'])
# ['38_n_1.png', '38_w_8.png', '38_w_1.png']
#
# dict_keys(['10', '18', '35', '1', '23', '57', '8', '16', '45', '25', '46', '15', '31', '47', '7', '59', '13', '21', '29', '38', '17', '60', '11', '52', '40', '44', '12', '4', '64', '26', '37', '48', '32', '2', '14', '27', '62', '3', '24', '61', '34', '41', '28', '50', '6', '42', '55', '49', '51', '19', '9', '56', '36', '22', '5', '30', '43', '53', '58', '54', '63', '39', '33', '20'])
# ['38_n_8.png', '38_w_1.png']
# dict_keys(['10', '18', '35', '1', '23', '57', '8', '16', '45', '25', '46', '15', '31', '47', '7', '59', '13', '21', '29', '38', '17', '60', '11', '52', '40', '44', '12', '4', '64', '26', '37', '48', '32', '2', '14', '27', '62', '3', '24', '61', '34', '41', '28', '50', '6', '42', '55', '49', '51', '19', '9', '56', '36', '22', '5', '30', '43', '53', '58', '54', '63', '39', '33', '20'])
# ['38_n_1.png', '38_w_2.png', '38_w_8.png']
#
# dict_keys(['10', '18', '35', '1', '23', '57', '8', '16', '45', '25', '46', '15', '31', '47', '7', '59', '13', '21', '29', '38', '17', '60', '11', '52', '40', '44', '12', '4', '64', '26', '37', '48', '32', '2', '14', '27', '62', '3', '24', '61', '34', '41', '28', '50', '6', '42', '55', '49', '51', '19', '9', '56', '36', '22', '5', '30', '43', '53', '58', '54', '63', '39', '33', '20'])
# ['38_n_8.png', '38_w_8.png']
# dict_keys(['10', '18', '35', '1', '23', '57', '8', '16', '45', '25', '46', '15', '31', '47', '7', '59', '13', '21', '29', '38', '17', '60', '11', '52', '40', '44', '12', '4', '64', '26', '37', '48', '32', '2', '14', '27', '62', '3', '24', '61', '34', '41', '28', '50', '6', '42', '55', '49', '51', '19', '9', '56', '36', '22', '5', '30', '43', '53', '58', '54', '63', '39', '33', '20'])
# ['38_n_1.png', '38_w_2.png', '38_w_1.png']
